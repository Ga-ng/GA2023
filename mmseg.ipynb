# %%
# !ls
# !cd mmsegmentation-main
# !ls
# Out:
# HRNet.py   imagenet_classes.txt  nohup.out
# README.md  mmseg.ipynb		 semantic-segmentation-pytorch-master
# dog.jpg    mmsegmentation-main	 work_dirs
# HRNet.py   imagenet_classes.txt  nohup.out
# README.md  mmseg.ipynb		 semantic-segmentation-pytorch-master
# dog.jpg    mmsegmentation-main	 work_dirs

# %%
ROOT = 'mmsegmentation-main/'

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot

config_path = ROOT+ 'configs/pspnet/pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py'
checkpoint_path = ROOT + 'checkpoints/pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
img_path = ROOT + 'demo/DJI_20230503105140_0127_W.JPG'


# build the model from a config file and a checkpoint file
model = init_model(config_path, checkpoint_path, device='cuda:0')

# inference on given image
result = inference_model(model, img_path)

# display the segmentation result
vis_image = show_result_pyplot(model, img_path, result)

# # save the visualization result, the output image would be found at the path `work_dirs/result.png`
# vis_iamge = show_result_pyplot(model, img_path, result, out_file='work_dirs/pspnet.png')

# # Modify the time of displaying images, note that 0 is the special value that means "forever"
# vis_image = show_result_pyplot(model, img_path, result, wait_time=5)
# Out:
# /home/gang/바탕화면/GA2023/mmsegmentation-main/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/gang/바탕화면/GA2023/mmsegmentation-main/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: mmsegmentation-main/checkpoints/pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# isaid
# [[128, 64, 128], [244, 35, 232], [70, 70, 70], [102, 102, 156], [190, 153, 153], [153, 153, 153], [250, 170, 30], [220, 220, 0], [107, 142, 35], [152, 251, 152], [70, 130, 180], [220, 20, 60], [255, 0, 0], [0, 0, 142], [0, 0, 70], [0, 60, 100], [0, 80, 100], [0, 0, 230], [119, 11, 32]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 15
#      12 result = inference_model(model, img_path)
#      14 # display the segmentation result
# ---> 15 vis_image = show_result_pyplot(model, img_path, result)
#
# File ~/바탕화면/GA2023/mmsegmentation-main/mmseg/apis/inference.py:214, in show_result_pyplot(model, img, result, opacity, title, draw_gt, draw_pred, wait_time, show, save_dir, out_file)
#     203 visualizer.add_datasample(
#     204     name=title,
#     205     image=image,
#    (...)
#     210     out_file=out_file,
#     211     show=show)
#     212 vis_img = visualizer.get_image()
# --> 214 print(visualizer.dataset_name)
#     216 return vis_img
#
# AttributeError: 'SegLocalVisualizer' object has no attribute 'dataset_name'

# %%
type(vis_image)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
plt.imshow(vis_image)

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot

config_path = ROOT+ 'configs/hrnet/fcn_hr18_4xb4-80k_isaid-896x896.py'
checkpoint_path = ROOT + 'checkpoints/fcn_hr18_4x4_896x896_80k_isaid_20220110_182230-49bf752e.pth'
img_path = ROOT + 'demo/DJI_20230503105140_0127_W.JPG'


# build the model from a config file and a checkpoint file
model = init_model(config_path, checkpoint_path, device='cuda:0')

# inference on given image
result = inference_model(model, img_path)

# display the segmentation result
# vis_image = show_result_pyplot(model, img_path, result)

# save the visualization result, the output image would be found at the path `work_dirs/result.png`
vis_iamge = show_result_pyplot(model, img_path, result, out_file='work_dirs/hrnet.png')

# Modify the time of displaying images, note that 0 is the special value that means "forever"
# vis_image = show_result_pyplot(model, img_path, result, wait_time=5)
# Out:
# Loads checkpoint by local backend from path: mmsegmentation-main/checkpoints/fcn_hr18_4x4_896x896_80k_isaid_20220110_182230-49bf752e.pth
# [[128, 64, 128], [244, 35, 232], [70, 70, 70], [102, 102, 156], [190, 153, 153], [153, 153, 153], [250, 170, 30], [220, 220, 0], [107, 142, 35], [152, 251, 152], [70, 130, 180], [220, 20, 60], [255, 0, 0], [0, 0, 142], [0, 0, 70], [0, 60, 100], [0, 80, 100], [0, 0, 230], [119, 11, 32]]
# ['road', 'sidewalk', 'building', 'wall', 'fence', 'pole', 'traffic light', 'traffic sign', 'vegetation', 'terrain', 'sky', 'person', 'rider', 'car', 'truck', 'bus', 'train', 'motorcycle', 'bicycle']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 18
#      12 result = inference_model(model, img_path)
#      14 # display the segmentation result
#      15 # vis_image = show_result_pyplot(model, img_path, result)
#      16
#      17 # save the visualization result, the output image would be found at the path `work_dirs/result.png`
# ---> 18 vis_iamge = show_result_pyplot(model, img_path, result, out_file='work_dirs/hrnet.png')
#
# File ~/바탕화면/GA2023/mmsegmentation-main/mmseg/apis/inference.py:203, in show_result_pyplot(model, img, result, opacity, title, draw_gt, draw_pred, wait_time, show, save_dir, out_file)
#     196 visualizer = SegLocalVisualizer(
#     197     vis_backends=[dict(type='LocalVisBackend')],
#     198     save_dir=save_dir,
#     199     alpha=opacity)
#     200 visualizer.dataset_meta = dict(
#     201     classes=model.dataset_meta['classes'],
#     202     palette=model.dataset_meta['palette'])
# --> 203 visualizer.add_datasample(
#     204     name=title,
#     205     image=image,
#     206     data_sample=result,
#     207     draw_gt=draw_gt,
#     208     draw_pred=draw_pred,
#     209     wait_time=wait_time,
#     210     out_file=out_file,
#     211     show=show)
#     212 vis_img = visualizer.get_image()
#     214 return vis_img
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/dist/utils.py:366, in master_only.<locals>.wrapper(*args, **kwargs)
#     363 @functools.wraps(func)
#     364 def wrapper(*args, **kwargs):
#     365     if is_main_process():
# --> 366         return func(*args, **kwargs)
#
# File ~/바탕화면/GA2023/mmsegmentation-main/mmseg/visualization/local_visualizer.py:219, in SegLocalVisualizer.add_datasample(self, name, image, data_sample, draw_gt, draw_pred, show, wait_time, out_file, step)
#     214     pred_img_data = image
#     215     assert classes is not None, 'class information is ' \
#     216                                 'not provided when ' \
#     217                                 'visualizing semantic ' \
#     218                                 'segmentation results.'
# --> 219     pred_img_data = self._draw_sem_seg(pred_img_data,
#     220                                        data_sample.pred_sem_seg,
#     221                                        classes, palette)
#     223 if gt_img_data is not None and pred_img_data is not None:
#     224     drawn_img = np.concatenate((gt_img_data, pred_img_data), axis=1)
#
# File ~/바탕화면/GA2023/mmsegmentation-main/mmseg/visualization/local_visualizer.py:109, in SegLocalVisualizer._draw_sem_seg(self, image, sem_seg, classes, palette)
#     106 ids = ids[legal_indices]
#     107 labels = np.array(ids, dtype=np.int64)
# --> 109 colors = [palette[label] for label in labels]
#     111 self.set_image(image)
#     113 # draw semantic masks
#
# File ~/바탕화면/GA2023/mmsegmentation-main/mmseg/visualization/local_visualizer.py:109, in <listcomp>(.0)
#     106 ids = ids[legal_indices]
#     107 labels = np.array(ids, dtype=np.int64)
# --> 109 colors = [palette[label] for label in labels]
#     111 self.set_image(image)
#     113 # draw semantic masks
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot
ROOT = 'mmsegmentation-main/'

config_path = ROOT+ 'configs/segmenter/segmenter_vit-b_mask_8xb1-160k_ade20k-512x512.py'
checkpoint_path = ROOT + 'checkpoints/segmenter_vit-b_mask_8x1_512x512_160k_ade20k_20220105_151706-bc533b08.pth'
img_path = ROOT + 'demo/DJI_20230503105140_0127_W.JPG'
# img_path = ROOT + 'demo/demo.png'

# build the model from a config file and a checkpoint file
model = init_model(config_path, checkpoint_path, device='cuda:0')

# inference on given image
result = inference_model(model, img_path)

# display the segmentation result
# vis_image = show_result_pyplot(model, img_path, result)

# save the visualization result, the output image would be found at the path `work_dirs/result.png`
vis_iamge = show_result_pyplot(model, img_path, result, out_file='work_dirs/pspnet2.png')

# # Modify the time of displaying images, note that 0 is the special value that means "forever"
# vis_image = show_result_pyplot(model, img_path, result, wait_time=5)
# Out:
# /home/gang/바탕화면/GA2023/mmsegmentation-main/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/gang/바탕화면/GA2023/mmsegmentation-main/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: mmsegmentation-main/checkpoints/segmenter_vit-b_mask_8x1_512x512_160k_ade20k_20220105_151706-bc533b08.pth
# 06/08 22:19:57 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# print :  [[0, 0, 0], [0, 0, 63], [0, 63, 63], [0, 63, 0], [0, 63, 127], [0, 63, 191], [0, 63, 255], [0, 127, 63], [0, 127, 127], [0, 0, 127], [0, 0, 191], [0, 0, 255], [0, 191, 127], [0, 127, 191], [0, 127, 255], [0, 100, 155]]
# print_palette :  [[120, 120, 120], [180, 120, 120], [6, 230, 230], [80, 50, 50], [4, 200, 3], [120, 120, 80], [140, 140, 140], [204, 5, 255], [230, 230, 230], [4, 250, 7], [224, 5, 255], [235, 255, 7], [150, 5, 61], [120, 120, 70], [8, 255, 51], [255, 6, 82], [143, 255, 140], [204, 255, 4], [255, 51, 7], [204, 70, 3], [0, 102, 200], [61, 230, 250], [255, 6, 51], [11, 102, 255], [255, 7, 71], [255, 9, 224], [9, 7, 230], [220, 220, 220], [255, 9, 92], [112, 9, 255], [8, 255, 214], [7, 255, 224], [255, 184, 6], [10, 255, 71], [255, 41, 10], [7, 255, 255], [224, 255, 8], [102, 8, 255], [255, 61, 6], [255, 194, 7], [255, 122, 8], [0, 255, 20], [255, 8, 41], [255, 5, 153], [6, 51, 255], [235, 12, 255], [160, 150, 20], [0, 163, 255], [140, 140, 140], [250, 10, 15], [20, 255, 0], [31, 255, 0], [255, 31, 0], [255, 224, 0], [153, 255, 0], [0, 0, 255], [255, 71, 0], [0, 235, 255], [0, 173, 255], [31, 0, 255], [11, 200, 200], [255, 82, 0], [0, 255, 245], [0, 61, 255], [0, 255, 112], [0, 255, 133], [255, 0, 0], [255, 163, 0], [255, 102, 0], [194, 255, 0], [0, 143, 255], [51, 255, 0], [0, 82, 255], [0, 255, 41], [0, 255, 173], [10, 0, 255], [173, 255, 0], [0, 255, 153], [255, 92, 0], [255, 0, 255], [255, 0, 245], [255, 0, 102], [255, 173, 0], [255, 0, 20], [255, 184, 184], [0, 31, 255], [0, 255, 61], [0, 71, 255], [255, 0, 204], [0, 255, 194], [0, 255, 82], [0, 10, 255], [0, 112, 255], [51, 0, 255], [0, 194, 255], [0, 122, 255], [0, 255, 163], [255, 153, 0], [0, 255, 10], [255, 112, 0], [143, 255, 0], [82, 0, 255], [163, 255, 0], [255, 235, 0], [8, 184, 170], [133, 0, 255], [0, 255, 92], [184, 0, 255], [255, 0, 31], [0, 184, 255], [0, 214, 255], [255, 0, 112], [92, 255, 0], [0, 224, 255], [112, 224, 255], [70, 184, 160], [163, 0, 255], [153, 0, 255], [71, 255, 0], [255, 0, 163], [255, 204, 0], [255, 0, 143], [0, 255, 235], [133, 255, 0], [255, 0, 235], [245, 0, 255], [255, 0, 122], [255, 245, 0], [10, 190, 212], [214, 255, 0], [0, 204, 255], [20, 0, 255], [255, 255, 0], [0, 153, 255], [0, 41, 255], [0, 255, 204], [41, 0, 255], [41, 255, 0], [173, 0, 255], [0, 245, 255], [71, 0, 255], [122, 0, 255], [0, 255, 184], [0, 92, 255], [184, 255, 0], [0, 133, 255], [255, 214, 0], [25, 194, 194], [102, 255, 0], [92, 0, 255]]
# print_classes :  ('wall', 'building', 'sky', 'floor', 'tree', 'ceiling', 'road', 'bed ', 'windowpane', 'grass', 'cabinet', 'sidewalk', 'person', 'earth', 'door', 'table', 'mountain', 'plant', 'curtain', 'chair', 'car', 'water', 'painting', 'sofa', 'shelf', 'house', 'sea', 'mirror', 'rug', 'field', 'armchair', 'seat', 'fence', 'desk', 'rock', 'wardrobe', 'lamp', 'bathtub', 'railing', 'cushion', 'base', 'box', 'column', 'signboard', 'chest of drawers', 'counter', 'sand', 'sink', 'skyscraper', 'fireplace', 'refrigerator', 'grandstand', 'path', 'stairs', 'runway', 'case', 'pool table', 'pillow', 'screen door', 'stairway', 'river', 'bridge', 'bookcase', 'blind', 'coffee table', 'toilet', 'flower', 'book', 'hill', 'bench', 'countertop', 'stove', 'palm', 'kitchen island', 'computer', 'swivel chair', 'boat', 'bar', 'arcade machine', 'hovel', 'bus', 'towel', 'light', 'truck', 'tower', 'chandelier', 'awning', 'streetlight', 'booth', 'television receiver', 'airplane', 'dirt track', 'apparel', 'pole', 'land', 'bannister', 'escalator', 'ottoman', 'bottle', 'buffet', 'poster', 'stage', 'van', 'ship', 'fountain', 'conveyer belt', 'canopy', 'washer', 'plaything', 'swimming pool', 'stool', 'barrel', 'basket', 'waterfall', 'tent', 'bag', 'minibike', 'cradle', 'oven', 'ball', 'food', 'step', 'tank', 'trade name', 'microwave', 'pot', 'animal', 'bicycle', 'lake', 'dishwasher', 'screen', 'blanket', 'sculpture', 'hood', 'sconce', 'vase', 'traffic light', 'tray', 'ashcan', 'fan', 'pier', 'crt screen', 'plate', 'monitor', 'bulletin board', 'shower', 'radiator', 'glass', 'clock', 'flag')
# label: [26 20 13  9  6  1]
# palette: [[120, 120, 120], [180, 120, 120], [6, 230, 230], [80, 50, 50], [4, 200, 3], [120, 120, 80], [140, 140, 140], [204, 5, 255], [230, 230, 230], [4, 250, 7], [224, 5, 255], [235, 255, 7], [150, 5, 61], [120, 120, 70], [8, 255, 51], [255, 6, 82], [143, 255, 140], [204, 255, 4], [255, 51, 7], [204, 70, 3], [0, 102, 200], [61, 230, 250], [255, 6, 51], [11, 102, 255], [255, 7, 71], [255, 9, 224], [9, 7, 230], [220, 220, 220], [255, 9, 92], [112, 9, 255], [8, 255, 214], [7, 255, 224], [255, 184, 6], [10, 255, 71], [255, 41, 10], [7, 255, 255], [224, 255, 8], [102, 8, 255], [255, 61, 6], [255, 194, 7], [255, 122, 8], [0, 255, 20], [255, 8, 41], [255, 5, 153], [6, 51, 255], [235, 12, 255], [160, 150, 20], [0, 163, 255], [140, 140, 140], [250, 10, 15], [20, 255, 0], [31, 255, 0], [255, 31, 0], [255, 224, 0], [153, 255, 0], [0, 0, 255], [255, 71, 0], [0, 235, 255], [0, 173, 255], [31, 0, 255], [11, 200, 200], [255, 82, 0], [0, 255, 245], [0, 61, 255], [0, 255, 112], [0, 255, 133], [255, 0, 0], [255, 163, 0], [255, 102, 0], [194, 255, 0], [0, 143, 255], [51, 255, 0], [0, 82, 255], [0, 255, 41], [0, 255, 173], [10, 0, 255], [173, 255, 0], [0, 255, 153], [255, 92, 0], [255, 0, 255], [255, 0, 245], [255, 0, 102], [255, 173, 0], [255, 0, 20], [255, 184, 184], [0, 31, 255], [0, 255, 61], [0, 71, 255], [255, 0, 204], [0, 255, 194], [0, 255, 82], [0, 10, 255], [0, 112, 255], [51, 0, 255], [0, 194, 255], [0, 122, 255], [0, 255, 163], [255, 153, 0], [0, 255, 10], [255, 112, 0], [143, 255, 0], [82, 0, 255], [163, 255, 0], [255, 235, 0], [8, 184, 170], [133, 0, 255], [0, 255, 92], [184, 0, 255], [255, 0, 31], [0, 184, 255], [0, 214, 255], [255, 0, 112], [92, 255, 0], [0, 224, 255], [112, 224, 255], [70, 184, 160], [163, 0, 255], [153, 0, 255], [71, 255, 0], [255, 0, 163], [255, 204, 0], [255, 0, 143], [0, 255, 235], [133, 255, 0], [255, 0, 235], [245, 0, 255], [255, 0, 122], [255, 245, 0], [10, 190, 212], [214, 255, 0], [0, 204, 255], [20, 0, 255], [255, 255, 0], [0, 153, 255], [0, 41, 255], [0, 255, 204], [41, 0, 255], [41, 255, 0], [173, 0, 255], [0, 245, 255], [71, 0, 255], [122, 0, 255], [0, 255, 184], [0, 92, 255], [184, 255, 0], [0, 133, 255], [255, 214, 0], [25, 194, 194], [102, 255, 0], [92, 0, 255]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 19
#      13 result = inference_model(model, img_path)
#      15 # display the segmentation result
#      16 # vis_image = show_result_pyplot(model, img_path, result)
#      17
#      18 # save the visualization result, the output image would be found at the path `work_dirs/result.png`
# ---> 19 vis_iamge = show_result_pyplot(model, img_path, result, out_file='work_dirs/pspnet2.png')
#
# File ~/바탕화면/GA2023/mmsegmentation-main/mmseg/apis/inference.py:203, in show_result_pyplot(model, img, result, opacity, title, draw_gt, draw_pred, wait_time, show, save_dir, out_file)
#     196 visualizer = SegLocalVisualizer(
#     197     vis_backends=[dict(type='LocalVisBackend')],
#     198     save_dir=save_dir,
#     199     alpha=opacity)
#     200 visualizer.dataset_meta = dict(
#     201     classes=model.dataset_meta['classes'],
#     202     palette=model.dataset_meta['palette'])
# --> 203 visualizer.add_datasample(
#     204     name=title,
#     205     image=image,
#     206     data_sample=result,
#     207     draw_gt=draw_gt,
#     208     draw_pred=draw_pred,
#     209     wait_time=wait_time,
#     210     out_file=out_file,
#     211     show=show)
#     212 vis_img = visualizer.get_image()
#     214 return vis_img
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/dist/utils.py:366, in master_only.<locals>.wrapper(*args, **kwargs)
#     363 @functools.wraps(func)
#     364 def wrapper(*args, **kwargs):
#     365     if is_main_process():
# --> 366         return func(*args, **kwargs)
#
# File ~/바탕화면/GA2023/mmsegmentation-main/mmseg/visualization/local_visualizer.py:224, in SegLocalVisualizer.add_datasample(self, name, image, data_sample, draw_gt, draw_pred, show, wait_time, out_file, step)
#     219     pred_img_data = image
#     220     assert classes is not None, 'class information is ' \
#     221                                 'not provided when ' \
#     222                                 'visualizing semantic ' \
#     223                                 'segmentation results.'
# --> 224     pred_img_data = self._draw_sem_seg(pred_img_data,
#     225                                        data_sample.pred_sem_seg,
#     226                                        classes, palette)
#     228 if gt_img_data is not None and pred_img_data is not None:
#     229     drawn_img = np.concatenate((gt_img_data, pred_img_data), axis=1)
#
# File ~/바탕화면/GA2023/mmsegmentation-main/mmseg/visualization/local_visualizer.py:117, in SegLocalVisualizer._draw_sem_seg(self, image, sem_seg, classes, palette)
#     115 # draw semantic masks
#     116 for label, color in zip(labels, colors):
# --> 117     self.draw_binary_masks(
#     118         sem_seg == label, colors=[color], alphas=self.alpha)
#     120 return self.get_image()
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/dist/utils.py:366, in master_only.<locals>.wrapper(*args, **kwargs)
#     363 @functools.wraps(func)
#     364 def wrapper(*args, **kwargs):
#     365     if is_main_process():
# --> 366         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:875, in Visualizer.draw_binary_masks(self, binary_masks, colors, alphas)
#     871 assert binary_masks.dtype == np.bool_, (
#     872     'The dtype of binary_masks should be np.bool_, '
#     873     f'but got {binary_masks.dtype}')
#     874 binary_masks = binary_masks.astype('uint8') * 255
# --> 875 img = self.get_image()
#     876 if binary_masks.ndim == 2:
#     877     binary_masks = binary_masks[None]
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/dist/utils.py:366, in master_only.<locals>.wrapper(*args, **kwargs)
#     363 @functools.wraps(func)
#     364 def wrapper(*args, **kwargs):
#     365     if is_main_process():
# --> 366         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:313, in Visualizer.get_image(self)
#     307 """Get the drawn image. The format is RGB.
#     308
#     309 Returns:
#     310     np.ndarray: the drawn image which channel is RGB.
#     311 """
#     312 assert self._image is not None, 'Please set image using `set_image`'
# --> 313 return img_from_canvas(self.fig_save_canvas)
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/visualization/utils.py:240, in img_from_canvas(canvas)
#     231 def img_from_canvas(canvas: 'FigureCanvasAgg') -> np.ndarray:
#     232     """Get RGB image from ``FigureCanvasAgg``.
#     233
#     234     Args:
#    (...)
#     238         np.ndarray: the output of image in RGB.
#     239     """  # noqa: E501
# --> 240     s, (width, height) = canvas.print_to_buffer()
#     241     buffer = np.frombuffer(s, dtype='uint8')
#     242     img_rgba = buffer.reshape(height, width, 4)
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:512, in FigureCanvasAgg.print_to_buffer(self)
#     511 def print_to_buffer(self):
# --> 512     FigureCanvasAgg.draw(self)
#     513     renderer = self.get_renderer()
#     514     return (bytes(renderer.buffer_rgba()),
#     515             (int(renderer.width), int(renderer.height)))
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/figure.py:3140, in Figure.draw(self, renderer)
#    3137         # ValueError can occur when resizing a window.
#    3139 self.patch.draw(renderer)
# -> 3140 mimage._draw_list_compositing_images(
#    3141     renderer, self, artists, self.suppressComposite)
#    3143 for sfig in self.subfigs:
#    3144     sfig.draw(renderer)
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/axes/_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/image.py:641, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     639         renderer.draw_image(gc, l, b, im, trans)
#     640 else:
# --> 641     im, l, b, trans = self.make_image(
#     642         renderer, renderer.get_image_magnification())
#     643     if im is not None:
#     644         renderer.draw_image(gc, l, b, im)
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/image.py:949, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     946 transformed_bbox = TransformedBbox(bbox, trans)
#     947 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     948         else self.figure.bbox)
# --> 949 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     950                         magnification, unsampled=unsampled)
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/image.py:553, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     551     A = _rgb_to_rgba(A)
#     552 alpha = self._get_scalar_alpha()
# --> 553 output_alpha = _resample(  # resample alpha channel
#     554     self, A[..., 3], out_shape, t, alpha=alpha)
#     555 output = _resample(  # resample rgb channels
#     556     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     557 output[..., 3] = output_alpha  # recombine rgb and alpha
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/matplotlib/image.py:207, in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     205 if resample is None:
#     206     resample = image_obj.get_resample()
# --> 207 _image.resample(data, out, transform,
#     208                 _interpd_[interpolation],
#     209                 resample,
#     210                 alpha,
#     211                 image_obj.get_filternorm(),
#     212                 image_obj.get_filterrad())
#     213 return out
#
# KeyboardInterrupt:

# %%
plt.imshow(vis_image)

# %%
from PIL import Image
ROOT = 'mmsegmentation-main/'

image = Image.open(ROOT+'demo/DJI_20230503105140_0127_W.JPG')

croped = image.crop((0,0,1500,2000))

croped.save(ROOT+'demo/croped.JPG')

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot
ROOT = 'mmsegmentation-main/'


config_path = ROOT+ 'configs/segmenter/segmenter_vit-s_fcn_8xb1-160k_ade20k-512x512.py'
checkpoint_path = ROOT + 'checkpoints/segmenter_vit-s_linear_8x1_512x512_160k_ade20k_20220105_151713-39658c46.pth'
# img_path = ROOT + 'demo/croped.JPG'
img_path = ROOT + 'demo/DJI_20230503105140_0127_W.JPG'

# build the model from a config file and a checkpoint file
model = init_model(config_path, checkpoint_path, device='cuda:0')

# inference on given image
result = inference_model(model, img_path)

# display the segmentation result
# vis_image = show_result_pyplot(model, img_path, result)

# save the visualization result, the output image would be found at the path `work_dirs/result.png`
vis_iamge = show_result_pyplot(model, img_path, result, out_file='work_dirs/segmenter.png')

# # Modify the time of displaying images, note that 0 is the special value that means "forever"
# vis_image = show_result_pyplot(model, img_path, result, wait_time=5)
# Out:
# /home/gang/바탕화면/GA2023/mmsegmentation-main/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/gang/바탕화면/GA2023/mmsegmentation-main/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: mmsegmentation-main/checkpoints/segmenter_vit-s_linear_8x1_512x512_160k_ade20k_20220105_151713-39658c46.pth
# 06/08 22:24:34 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# print :  [[0, 0, 0], [0, 0, 63], [0, 63, 63], [0, 63, 0], [0, 63, 127], [0, 63, 191], [0, 63, 255], [0, 127, 63], [0, 127, 127], [0, 0, 127], [0, 0, 191], [0, 0, 255], [0, 191, 127], [0, 127, 191], [0, 127, 255], [0, 100, 155]]
# label: [138 115 108  83  53  43  41  32  26  21  13  11   9   6   3   1   0]
# palette: [[120, 120, 120], [180, 120, 120], [6, 230, 230], [80, 50, 50], [4, 200, 3], [120, 120, 80], [140, 140, 140], [204, 5, 255], [230, 230, 230], [4, 250, 7], [224, 5, 255], [235, 255, 7], [150, 5, 61], [120, 120, 70], [8, 255, 51], [255, 6, 82], [143, 255, 140], [204, 255, 4], [255, 51, 7], [204, 70, 3], [0, 102, 200], [61, 230, 250], [255, 6, 51], [11, 102, 255], [255, 7, 71], [255, 9, 224], [9, 7, 230], [220, 220, 220], [255, 9, 92], [112, 9, 255], [8, 255, 214], [7, 255, 224], [255, 184, 6], [10, 255, 71], [255, 41, 10], [7, 255, 255], [224, 255, 8], [102, 8, 255], [255, 61, 6], [255, 194, 7], [255, 122, 8], [0, 255, 20], [255, 8, 41], [255, 5, 153], [6, 51, 255], [235, 12, 255], [160, 150, 20], [0, 163, 255], [140, 140, 140], [250, 10, 15], [20, 255, 0], [31, 255, 0], [255, 31, 0], [255, 224, 0], [153, 255, 0], [0, 0, 255], [255, 71, 0], [0, 235, 255], [0, 173, 255], [31, 0, 255], [11, 200, 200], [255, 82, 0], [0, 255, 245], [0, 61, 255], [0, 255, 112], [0, 255, 133], [255, 0, 0], [255, 163, 0], [255, 102, 0], [194, 255, 0], [0, 143, 255], [51, 255, 0], [0, 82, 255], [0, 255, 41], [0, 255, 173], [10, 0, 255], [173, 255, 0], [0, 255, 153], [255, 92, 0], [255, 0, 255], [255, 0, 245], [255, 0, 102], [255, 173, 0], [255, 0, 20], [255, 184, 184], [0, 31, 255], [0, 255, 61], [0, 71, 255], [255, 0, 204], [0, 255, 194], [0, 255, 82], [0, 10, 255], [0, 112, 255], [51, 0, 255], [0, 194, 255], [0, 122, 255], [0, 255, 163], [255, 153, 0], [0, 255, 10], [255, 112, 0], [143, 255, 0], [82, 0, 255], [163, 255, 0], [255, 235, 0], [8, 184, 170], [133, 0, 255], [0, 255, 92], [184, 0, 255], [255, 0, 31], [0, 184, 255], [0, 214, 255], [255, 0, 112], [92, 255, 0], [0, 224, 255], [112, 224, 255], [70, 184, 160], [163, 0, 255], [153, 0, 255], [71, 255, 0], [255, 0, 163], [255, 204, 0], [255, 0, 143], [0, 255, 235], [133, 255, 0], [255, 0, 235], [245, 0, 255], [255, 0, 122], [255, 245, 0], [10, 190, 212], [214, 255, 0], [0, 204, 255], [20, 0, 255], [255, 255, 0], [0, 153, 255], [0, 41, 255], [0, 255, 204], [41, 0, 255], [41, 255, 0], [173, 0, 255], [0, 245, 255], [71, 0, 255], [122, 0, 255], [0, 255, 184], [0, 92, 255], [184, 255, 0], [0, 133, 255], [255, 214, 0], [25, 194, 194], [102, 255, 0], [92, 0, 255]]

# %%
plt.imshow(vis_iamge)

# %%
plt.imshow(vis_iamge)

# %%
plt.imshow(vis_iamge)
